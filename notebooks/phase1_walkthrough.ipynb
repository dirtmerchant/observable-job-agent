# %% [markdown]
# # Job Scout — Phase 1 Walkthrough
#
# **Build → Evaluate → Self-Improve.** This is Phase 1: a working, fully-traced
# job-matching agent. This notebook is a guided runner — verify your environment,
# run the agent on a fixture CV, and explore the Opik trace.
#
# **Learning materials:**
# - [LangGraph](https://langchain-ai.github.io/langgraph/) · [Opik](https://www.comet.com/docs/opik/) · [Gradio](https://www.gradio.app/) · [Adzuna API](https://developer.adzuna.com/)
#
# > The agent's LLM output is *deliberately unoptimized* in Phase 1. We measure it in Phase 2 and improve it in Phase 3.

# %% [markdown]
# ## 1. Environment check
#
# Confirm the project imports and the key dependencies are installed.

# %%
import importlib.metadata as m

for pkg in ["langgraph", "langchain", "opik", "gradio", "pypdf", "pydantic"]:
    print(f"{pkg:12s} {m.version(pkg)}")

from job_scout.config import get_settings
settings = get_settings()
print("\nmodel:", settings.scout_model)
print("opik enabled:", settings.has_opik)
print("adzuna keys:", settings.has_adzuna)
# Out:
# langgraph    1.2.9
# langchain    1.3.13
# opik         2.1.24
# gradio       6.20.0
# pypdf        6.14.2
# pydantic     2.13.4
#
# model: openai:gpt-4o-mini
# opik enabled: False
# adzuna keys: False

# %% [markdown]
# ## 2. Service / key checks
#
# The app runs with **zero keys** (Remotive + cached jobs, no tracing). For the full
# lesson set `OPENAI_API_KEY`, `OPIK_API_KEY` / `OPIK_WORKSPACE`, and optionally
# `ADZUNA_APP_ID` / `ADZUNA_APP_KEY` in `.env`.

# %%
checks = {
    "LLM key (OPENAI_API_KEY)": bool(settings.openai_api_key.get_secret_value()),
    "Opik tracing": settings.has_opik,
    "Adzuna (live intl jobs)": settings.has_adzuna,
}
for name, ok in checks.items():
    print(f"[{'x' if ok else ' '}] {name}")
# Out:
# [ ] LLM key (OPENAI_API_KEY)
# [ ] Opik tracing
# [ ] Adzuna (live intl jobs)

# %% [markdown]
# ## 3. Read a fixture CV
#
# Four synthetic CVs ship in `data/fixture_cvs/`. Extraction is text-only (pypdf).

# %%
from pathlib import Path
from job_scout.tools.cv_reader import extract_cv_text

cv_path = Path("../data/fixture_cvs/senior_mle_eu.pdf")
cv_text = extract_cv_text(cv_path)
print(cv_text[:400])
# Out:
# Lukas Vogel
# Berlin, Germany  |  lukas.vogel@example.com  |  English, German
# Summary
# Senior Machine Learning Engineer with 8 years of experience shipping ML systems to production. Leads small teams,
# owns MLOps, and is open to remote or Berlin-based roles.
# Skills
# Python, PyTorch, TensorFlow, Kubernetes, Docker, AWS, GCP, MLflow, Kafka, Spark, feature stores, model serving,
# CI/CD, distributed trainin

# %% [markdown]
# ## 4. Run the agent
#
# One compiled graph: extract profile → fetch jobs (LLM picks the search args) → rank → maybe reformulate. We stream node-level status, exactly as the app does.

# %%
from uuid import uuid4
from job_scout.runner import run_once

result = run_once(cv_text, cv_path=str(cv_path), thread_id=str(uuid4()), tags=["phase-1", "notebook"])

print("failed:", result.failed)
if result.error_message:
    print("error:", result.error_message)
print("jobs fetched:", result.n_jobs_fetched, "| ranked:", result.n_jobs_ranked)
print("sources:", result.jobs_sources, "| reformulations:", result.reformulation_count)
print(f"cost ${result.cost_usd:.4f} · {result.latency_s}s")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 from uuid import uuid4
#       2 from job_scout.runner import run_once
#       3
# ----> 4 result = run_once(cv_text, cv_path=str(cv_path), thread_id=str(uuid4()), tags=["phase-1", "notebook"])
#       5
#       6 print("failed:", result.failed)
#       7 if result.error_message:
#
# File ~/repos/observable-job-agent/src/job_scout/runner.py:133, in run_once(cv_text, cv_path, thread_id, tags)
#     128 def run_once(cv_text: str, *, cv_path: str | None = None, thread_id: str, tags: list[str]) -> RunResult:
#     129     """Extract the profile then run the job search, returning the final result.
#     130
#     131     Used by the batch runner, which starts from raw CV text.
#     132     """
# --> 133     profile = extract_profile(cv_text, thread_id=thread_id, tags=tags)
#     134     result = RunResult()
#     135     for kind, payload in stream_search(profile, cv_text=cv_text, cv_path=cv_path, thread_id=thread_id, tags=tags):
#
# File ~/repos/observable-job-agent/src/job_scout/profile.py:44, in extract_profile(cv_text, thread_id, tags)
#      41 from job_scout.tracing import get_tracer
#      43 settings = get_settings()
# ---> 44 model = get_chat_model(settings.scout_model, temperature=0.0).with_structured_output(Profile)
#      46 tracer = get_tracer(thread_id, tags or ["extract"]) if thread_id else None
#      47 config = {"callbacks": [tracer]} if tracer else {}
#
# File ~/repos/observable-job-agent/src/job_scout/llm.py:43, in get_chat_model(model, temperature)
#      41 if model.startswith("openai:"):
#      42     _export_openai_key()
# ---> 43 return init_chat_model(model, temperature=temperature)
#
# File ~/repos/observable-job-agent/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:496, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     488     warnings.warn(
#     489         f"{config_prefix=} has been set but no fields are configurable. Set "
#     490         f"`configurable_fields=(...)` to specify the model params that are "
#     491         f"configurable.",
#     492         stacklevel=2,
#     493     )
#     495 if not configurable_fields:
# --> 496     return _init_chat_model_helper(
#     497         cast("str", model),
#     498         model_provider=model_provider,
#     499         **kwargs,
#     500     )
#     501 if model:
#     502     kwargs["model"] = model
#
# File ~/repos/observable-job-agent/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:520, in _init_chat_model_helper(model, model_provider, **kwargs)
#     518 model, model_provider = _parse_model(model, model_provider)
#     519 creator_func = _get_chat_model_creator(model_provider)
# --> 520 return creator_func(model=model, **kwargs)
#
# File ~/repos/observable-job-agent/.venv/lib/python3.12/site-packages/langchain/chat_models/base.py:35, in _call(cls, **kwargs)
#      33 def _call(cls: type[BaseChatModel], **kwargs: Any) -> BaseChatModel:
#      34     # TODO: replace with operator.call when lower bounding to Python 3.11
# ---> 35     return cls(**kwargs)
#
# File ~/repos/observable-job-agent/.venv/lib/python3.12/site-packages/langchain_core/load/serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/repos/observable-job-agent/.venv/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:1326, in BaseChatOpenAI.validate_environment(self)
#    1312         self.http_async_client = _build_proxied_async_httpx_client(
#    1313             proxy=self.openai_proxy,
#    1314             verify=global_ssl_context,
#    1315             socket_options=resolved_socket_options,
#    1316         )
#    1317     async_specific = {
#    1318         "http_client": self.http_async_client
#    1319         or _get_default_async_httpx_client(
#    (...)   1324         "api_key": async_api_key_value,
#    1325     }
# -> 1326     self.root_async_client = openai.AsyncOpenAI(
#    1327         **client_params,
#    1328         **async_specific,  # type: ignore[arg-type]
#    1329     )
#    1330     self.async_client = self.root_async_client.chat.completions
#    1331 return self
#
# File ~/repos/observable-job-agent/.venv/lib/python3.12/site-packages/openai/_client.py:826, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, provider, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     816 self.admin_api_key = admin_api_key if provider_runtime is None else None
#     818 if (
#     819     provider_runtime is None
#     820     and _enforce_credentials
#    (...)    824     and self.admin_api_key is None
#     825 ):
# --> 826     raise OpenAIError(
#     827         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     828     )
#     830 if organization is None and provider_runtime is None:
#     831     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.

# %% [markdown]
# ## 5. Explore the profile and rankings

# %%
p = result.profile
if p:
    print(f"{p.name} · {p.seniority} · {', '.join(p.primary_roles)}")
    print("skills:", ", ".join(p.skills))
print()
for r in result.ranked_jobs[:5]:
    print(f"[{r.fit_score:3d}] {r.job.title} @ {r.job.company} ({r.job.location})")
    print("     ", r.fit_explanation[:160])

# %% [markdown]
# ## 6. Explore the trace in Opik
#
# If tracing is enabled, open your `job-scout` project in Opik. You should see:
#
# - the **span tree** per node (extract_profile → fetch_jobs → rank_jobs → …),
# - **Show Agent Graph** working in the sidebar,
# - **per-run cost** (for OpenAI models),
# - the **CV PDF attached** to the trace.

# %%
from job_scout.tracing import opik_url
print("Opik project:", opik_url())

# %% [markdown]
# ## 7. Baseline batch
#
# `scripts/run_batch.py` runs ~50 cases (fixture CVs × locations + hard cases),
# tags traces `baseline-batch`, and writes `reports/baseline.json`. Its failures
# and weaknesses are documented in `reports/phase1_findings.md` — **and left
# unfixed** (that is Phase 3's job).
#
# ```bash
# uv run python scripts/run_batch.py --yes
# ```
#
# **Next:** Phase 2 adds the tailoring node and the full evaluation stack.
